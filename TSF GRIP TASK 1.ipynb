# %% [markdown]
# # GRIP : THE SPARK FOUNDATION

# %% [markdown]
# #### DATA SCIENCE AND BUSINESS ANALYTICS - INTERNSHIP

# %% [markdown]
# #### By SHRUTI PAL

# %%
# import requried libaries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# import data
url = "http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Data imported successfully")
s_data
# Out:
# Data imported successfully
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
X = s_data.iloc[:,:1]
y = s_data.iloc[:,1:]

# %%
X
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8

# %%
y
# Out:
#     Scores
# 0       21
# 1       47
# 2       27
# 3       75
# 4       30
# 5       20
# 6       88
# 7       60
# 8       81
# 9       25
# 10      85
# 11      62
# 12      41
# 13      42
# 14      17
# 15      95
# 16      30
# 17      24
# 18      67
# 19      69
# 20      30
# 21      54
# 22      35
# 23      76
# 24      86

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_test
# Out:
#     Hours
# 15    8.9
# 9     2.7
# 19    7.4
# 13    3.3
# 5     1.5
# 12    4.5
# 20    2.7

# %%
y_test.values
# Out:
# array([[95],
#        [25],
#        [69],
#        [42],
#        [20],
#        [41],
#        [30]], dtype=int64)

# %% [markdown]
# # TRAINING THE ALGORITHM

# %%
#spliting the data into training and testing sets
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %%
regressor.coef_
# Out:
# array([[9.83385595]])

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_
line
# Out:
#         Hours
# 0   26.677272
# 1   52.245298
# 2   33.560971
# 3   85.680408
# 4   36.511128
# 5   16.843416
# 6   92.564107
# 7   56.178840
# 8   83.713637
# 9   28.644044
# 10  77.813323
# 11  60.112383
# 12  46.344984
# 13  34.544357
# 14  12.909874
# 15  89.613950
# 16  26.677272
# 17  20.776959
# 18  62.079154
# 19  74.863166
# 20  28.644044
# 21  49.295141
# 22  39.461285
# 23  69.946238
# 24  78.796709

# %%
y=line
# Plotting for the test data
plt.scatter(X_train,y_train)
plt.show()

# %%
y_pred = regressor.predict(X_test) # Predicting the scores
y_pred
# Out:
# array([[89.61395039],
#        [28.64404351],
#        [74.86316647],
#        [34.54435708],
#        [16.84341637],
#        [46.34498422],
#        [28.64404351]])

# %%
df1=pd.DataFrame(y_pred,columns=["predicted score"])
df1
# Out:
#    predicted score
# 0        89.613950
# 1        28.644044
# 2        74.863166
# 3        34.544357
# 4        16.843416
# 5        46.344984
# 6        28.644044

# %%
df2=pd.DataFrame(y_test)
df2.reset_index()
df3=df2.reset_index(drop=True)
df3
# Out:
#    Scores
# 0      95
# 1      25
# 2      69
# 3      42
# 4      20
# 5      41
# 6      30

# %%
pd.concat([df1,df3],axis=1)
# Out:
#    predicted score  Scores
# 0        89.613950      95
# 1        28.644044      25
# 2        74.863166      69
# 3        34.544357      42
# 4        16.843416      20
# 5        46.344984      41
# 6        28.644044      30

# %%
# predictor score
hours = 9.25

own_pred = regressor.predict([[hours]])
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = [93.05579997]
# C:\Users\amitp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.600918120760757

# %%
print('Mean Squared Error:', 
      metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 24.660487198248227

# %% [markdown]
# ### Thank you !😊
